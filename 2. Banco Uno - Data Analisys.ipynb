# %% [markdown]
# <img src="credits3.png" style="width:95%;">

# %% [markdown]
# <h1 style="color:#0e535b; text-align: left">Banco Uno - Data Analisys</h1>
#
# <p style="text-align:justify">En este notebook se realizarán labores de Análisis de Datos del caso cuyo propósito final será intentar predecir la probabilidad de cumplimiento de pago de los clientes que tienen un crédito en el Banco Uno.</p>

# %% [markdown]
# <h3 style="color:#0e535b; text-align: left">1. Trabajando con datos no numéricos</h3>

# %% [markdown]
# <h4 style="color:#0e535b; text-align: left">1.1 Carga de Liberías</h4>
#
# <p style="text-align:justify">Se utilizarán librerías que permiten analizar los datos (pandas) y generar informe graficos y visualización de los datos.</p>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
credit = pd.read_excel("credit.xlsx")
credit.head()
# Out:
#    Unnamed: 0  LIMIT_BAL     SEX   EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  \
# 0           0      20000  female  university         1   24      2      2
# 1           1     120000  female  university         2   26     -1      2
# 2           2      90000  female  university         2   34      0      0
# 3           3      50000  female  university         1   37      0      0
# 4           4      50000    male  university         1   57     -1      0
#
#    PAY_3  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 0     -1     -1  ...          0          0          0         0       689
# 1      0      0  ...       3272       3455       3261         0      1000
# 2      0      0  ...      14331      14948      15549      1518      1500
# 3      0      0  ...      28314      28959      29547      2000      2019
# 4     -1      0  ...      20940      19146      19131      2000     36681
#
#    PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 0         0         0         0         0                     default
# 1      1000      1000         0      2000                     default
# 2      1000      1000      1000      5000                 not default
# 3      1200      1100      1069      1000                 not default
# 4     10000      9000       689       679                 not default
#
# [5 rows x 25 columns]

# %%
credit.drop(['Unnamed: 0'], axis=1,inplace=True)
credit.head(5)
# Out:
#    LIMIT_BAL     SEX   EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0      20000  female  university         1   24      2      2     -1     -1
# 1     120000  female  university         2   26     -1      2      0      0
# 2      90000  female  university         2   34      0      0      0      0
# 3      50000  female  university         1   37      0      0      0      0
# 4      50000    male  university         1   57     -1      0     -1      0
#
#    PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0     -2  ...          0          0          0         0       689         0
# 1      0  ...       3272       3455       3261         0      1000      1000
# 2      0  ...      14331      14948      15549      1518      1500      1000
# 3      0  ...      28314      28959      29547      2000      2019      1200
# 4      0  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 0         0         0         0                     default
# 1      1000         0      2000                     default
# 2      1000      1000      5000                 not default
# 3      1100      1069      1000                 not default
# 4      9000       689       679                 not default
#
# [5 rows x 24 columns]

# %% [markdown]
# <h4 style="color:#0e535b; text-align: left">1.2 Generación de las variables dummies:</h4>
#
# <p style="text-align:justify">Primeramente, se debe proceder a consultar el tipo de variables disponibles en el DataFrame, posteriormente se realiza la generación de las variables dummies que permiten graficar valores categóricos.</p>

# %%
credit.dtypes
# Out:
# LIMIT_BAL                      int64
# SEX                           object
# EDUCATION                     object
# MARRIAGE                       int64
# AGE                            int64
# PAY_0                          int64
# PAY_2                          int64
# PAY_3                          int64
# PAY_4                          int64
# PAY_5                          int64
# PAY_6                          int64
# BILL_AMT1                      int64
# BILL_AMT2                      int64
# BILL_AMT3                      int64
# BILL_AMT4                      int64
# BILL_AMT5                      int64
# BILL_AMT6                      int64
# PAY_AMT1                       int64
# PAY_AMT2                       int64
# PAY_AMT3                       int64
# PAY_AMT4                       int64
# PAY_AMT5                       int64
# PAY_AMT6                       int64
# default payment next month    object
# dtype: object

# %%
credit = pd.get_dummies(credit)
credit.dtypes
# Out:
# LIMIT_BAL                                 int64
# MARRIAGE                                  int64
# AGE                                       int64
# PAY_0                                     int64
# PAY_2                                     int64
# PAY_3                                     int64
# PAY_4                                     int64
# PAY_5                                     int64
# PAY_6                                     int64
# BILL_AMT1                                 int64
# BILL_AMT2                                 int64
# BILL_AMT3                                 int64
# BILL_AMT4                                 int64
# BILL_AMT5                                 int64
# BILL_AMT6                                 int64
# PAY_AMT1                                  int64
# PAY_AMT2                                  int64
# PAY_AMT3                                  int64
# PAY_AMT4                                  int64
# PAY_AMT5                                  int64
# PAY_AMT6                                  int64
# SEX_female                                uint8
# SEX_male                                  uint8
# EDUCATION_graduate school                 uint8
# EDUCATION_high school                     uint8
# EDUCATION_other                           uint8
# EDUCATION_university                      uint8
# default payment next month_default        uint8
# default payment next month_not default    uint8
# dtype: object

# %% [markdown]
# <h3 style="color:#0e535b; text-align: left">2. Analizando los datos</h3>

# %%
credit.describe()
# Out:
#             LIMIT_BAL     MARRIAGE          AGE        PAY_0        PAY_2  \
# count     2396.000000  2396.000000  2396.000000  2396.000000  2396.000000
# mean    165834.724541     1.580134    35.419866     0.004591    -0.136477
# std     129493.683277     0.525593     9.452344     1.123473     1.207902
# min      10000.000000     0.000000    21.000000    -2.000000    -2.000000
# 25%      50000.000000     1.000000    28.000000    -1.000000    -1.000000
# 50%     140000.000000     2.000000    34.000000     0.000000     0.000000
# 75%     230000.000000     2.000000    41.000000     0.000000     0.000000
# max    1000000.000000     3.000000    75.000000     8.000000     7.000000
#
#              PAY_3        PAY_4        PAY_5        PAY_6      BILL_AMT1  ...  \
# count  2396.000000  2396.000000  2396.000000  2396.000000    2396.000000  ...
# mean     -0.151920    -0.249165    -0.259599    -0.282137   51199.401085  ...
# std       1.247411     1.176359     1.156723     1.181852   77872.623393  ...
# min      -2.000000    -2.000000    -2.000000    -2.000000  -14386.000000  ...
# 25%      -1.000000    -1.000000    -1.000000    -1.000000    3125.000000  ...
# 50%       0.000000     0.000000     0.000000     0.000000   21111.500000  ...
# 75%       0.000000     0.000000     0.000000     0.000000   62921.250000  ...
# max       7.000000     7.000000     7.000000     8.000000  964511.000000  ...
#
#             PAY_AMT5       PAY_AMT6   SEX_female     SEX_male  \
# count    2396.000000    2396.000000  2396.000000  2396.000000
# mean     4984.977880    5149.928631     0.577629     0.422371
# std     16896.223773   20076.659470     0.494040     0.494040
# min         0.000000       0.000000     0.000000     0.000000
# 25%       247.750000       0.000000     0.000000     0.000000
# 50%      1500.000000    1328.000000     1.000000     0.000000
# 75%      4000.000000    4000.000000     1.000000     1.000000
# max    332000.000000  528666.000000     1.000000     1.000000
#
#        EDUCATION_graduate school  EDUCATION_high school  EDUCATION_other  \
# count                2396.000000            2396.000000      2396.000000
# mean                    0.379382               0.163606         0.007513
# std                     0.485335               0.369995         0.086367
# min                     0.000000               0.000000         0.000000
# 25%                     0.000000               0.000000         0.000000
# 50%                     0.000000               0.000000         0.000000
# 75%                     1.000000               0.000000         0.000000
# max                     1.000000               1.000000         1.000000
#
#        EDUCATION_university  default payment next month_default  \
# count           2396.000000                         2396.000000
# mean               0.449499                            0.216611
# std                0.497547                            0.412021
# min                0.000000                            0.000000
# 25%                0.000000                            0.000000
# 50%                0.000000                            0.000000
# 75%                1.000000                            0.000000
# max                1.000000                            1.000000
#
#        default payment next month_not default
# count                             2396.000000
# mean                                 0.783389
# std                                  0.412021
# min                                  0.000000
# 25%                                  1.000000
# 50%                                  1.000000
# 75%                                  1.000000
# max                                  1.000000
#
# [8 rows x 29 columns]

# %% [markdown]
# <h4 style="color:#0e535b; text-align: left">2.1 Visualización de los Datos</h4>
#
# <p style="text-align:justify">A continuación se procederá a realizar preguntas que permitan analizar los datos generando una visualización grafica de tal forma que nos lleven a una respuesta.</p>
#
# <ol>
#     <li>¿Cuál es el grupo etario que tiene mayor cantidad de créditos?</li>
#     <li>¿Cuál es el grupo etario que ha tomado mayor cantidad de dinero prestado en Unidades Monetarias?</li>
#     <li>¿Cuál es la cantidad de créditos que se encuentran atrasados?</li>
#     <li>¿Cuál es la relación entre el estado del préstamo y la cantidad del préstamo?</li>
# </ol>

# %% [markdown]
# <h5 style="color:#0e535b; text-align: left">2.1.1 ¿Cuál es el grupo etario que tiene mayor cantidad de créditos?</h5>
#
# Debido a que los rangos de edad varían entre 21 y 75 años, se crearán tres grupos etarios (bins):
# * Personas entre 21 y 39 años - Adulto temprano
# * Personas entre 40 y 57 años - Adultos medio
# * Personas entre 58 y 75 años - Adulto mayor

# %%
#Remove all axis
mpl.rcParams["axes.spines.bottom"] = True
mpl.rcParams["axes.spines.left"] = False
mpl.rcParams["axes.spines.right"] = False
mpl.rcParams["axes.spines.top"] = False

# %%
bins = np.linspace(21,75,4)
bins
# Out:
# array([21., 39., 57., 75.])

# %%
categorias = ["Adulto temprano", "Adulto Medio", "Adulto Mayor"]
credit["AGE(cat)"] = pd.cut(credit["AGE"], bins, labels=categorias, include_lowest=True)
dfTemp = credit[["AGE","AGE(cat)"]]
dfTemp.head(5)
# Out:
#    AGE         AGE(cat)
# 0   24  Adulto temprano
# 1   26  Adulto temprano
# 2   34  Adulto temprano
# 3   37  Adulto temprano
# 4   57     Adulto Medio

# %%
gf = credit.groupby(['AGE(cat)']).count()
gf = gf.iloc[:,:1]
gf = gf.sort_values('AGE(cat)', ascending = False)
gf
# Out:
#                  LIMIT_BAL
# AGE(cat)
# Adulto Mayor            45
# Adulto Medio           672
# Adulto temprano       1679

# %%
fig, ax = plt.subplots(1,1, figsize=(15,6.9), dpi=70)

eje_x = gf.index.tolist()
data = gf['LIMIT_BAL'].tolist()

bar_colors = ['#89abb4', '#f2e5f9', '#ff8a84']
ax.pie(data, labels=eje_x,colors=bar_colors, autopct='%1.1f%%')

#--------------------------------------------------------------------------------------------------------------------#
#--------------------CONFIGURACION DE LOS TITULOS, SUBTITULOS Y EJES DEL GRAFICO ------------------------------------#
#--------------------------------------------------------------------------------------------------------------------#
#FORMATO DEL TITULO
title = "Grafico 1: Créditos"
plt.suptitle(title,
             horizontalalignment = 'left',
             x = 0.001,
             y = 0.87,
             transform = fig.transFigure,
             fontsize = 20,
             fontweight = "bold",
             fontfamily = "serif") 

#FORMATO DEL SUBTITULO
subTitle = "Porcentaje de créditos según grupo etario (en cantidad)"
ax.set_title(subTitle,
             horizontalalignment = 'left',
             x = 0.001,
             y = 0.80,
             transform = fig.transFigure,
             fontsize = 15,
             fontweight = "regular",
             fontfamily = "serif")

#CONFIGURACION LA UBICACION DEL GRAFICO
plt.subplots_adjust(top=0.85)
plt.show()

# %% [markdown]
# <h5 style="color:#0e535b; text-align: left">2.1.2 ¿Cuál es el grupo etario que ha tomado mayor cantidad de dinero prestado en Unidades Monetarias?</h5>
#
# <p style="text-align:justify">Se mantendrán los mismos grupos etarios que en el ejemplo anterior.</p>

# %%
dfTemp = credit[["AGE","AGE(cat)","LIMIT_BAL"]]
dfTemp.head(5)
# Out:
#    AGE         AGE(cat)  LIMIT_BAL
# 0   24  Adulto temprano      20000
# 1   26  Adulto temprano     120000
# 2   34  Adulto temprano      90000
# 3   37  Adulto temprano      50000
# 4   57     Adulto Medio      50000

# %%
gf = credit.groupby(['AGE(cat)']).sum()
gf = gf.iloc[:,:1]
gf = gf.sort_values('AGE(cat)', ascending = False)
gf
# Out:
#                  LIMIT_BAL
# AGE(cat)
# Adulto Mayor       8430000
# Adulto Medio     119410000
# Adulto temprano  269500000

# %%
fig, ax = plt.subplots(1,1, figsize=(15,6.9), dpi=70)

eje_x = gf.index.tolist()
data = gf['LIMIT_BAL'].tolist()

bar_colors = ['#89abb4', '#f2e5f9', '#ff8a84']
ax.pie(data, labels=eje_x,colors=bar_colors, autopct='%1.1f%%')

#--------------------------------------------------------------------------------------------------------------------#
#--------------------CONFIGURACION DE LOS TITULOS, SUBTITULOS Y EJES DEL GRAFICO ------------------------------------#
#--------------------------------------------------------------------------------------------------------------------#
#FORMATO DEL TITULO
title = "Grafico 2: Créditos"
plt.suptitle(title,
             horizontalalignment = 'left',
             x = 0.001,
             y = 0.87,
             transform = fig.transFigure,
             fontsize = 20,
             fontweight = "bold",
             fontfamily = "serif") 

#FORMATO DEL SUBTITULO
subTitle = "Porcentaje de créditos según grupo etario (en UM)"
ax.set_title(subTitle,
             horizontalalignment = 'left',
             x = 0.001,
             y = 0.80,
             transform = fig.transFigure,
             fontsize = 15,
             fontweight = "regular",
             fontfamily = "serif")

#CONFIGURACION LA UBICACION DEL GRAFICO
plt.subplots_adjust(top=0.85)
plt.show()

# %% [markdown]
# <h5 style="color:#0e535b; text-align: left">2.1.3 ¿Cuál es la cantidad de préstamos que se encuentran atrasados?</h5>
#
# <p style="text-align:justify">Al mes de setiembre de 2005, última fecha de actualización de los datos, los créditos con pagos atrasados tienen un número positivo y diferente de 0 en la columna de PAY_0, los demás son préstamos al día o pagados completamente. </p>

# %%
categorias = ["Préstamo Al día", "Atrasado 1m", "Atrasado 2m", "Atrasado 3m", "Atrasado 4m", "Atrasado 5m", "Atrasado 6m", "Atrasado 7m", "Atrasado 8m"]
credit["PAY_0(cat)"] = pd.cut(credit["PAY_0"], [-8.,  0.,  1.,  2.,  3.,  4.,  5.,  6.,  7.,  8.], labels=categorias, include_lowest=True)
dfTemp = credit[["PAY_0","PAY_0(cat)"]]

# %%
fig,ax=plt.subplots(1,1,figsize=(16,6.9),dpi=100)

plt.hist(dfTemp["PAY_0(cat)"])

#Formato del grafico
#-------Titulo y Subtitulo del grafico
title_t = "Gráfico 3: Créditos clasificados por estado"
ax.set_title(title_t,
             horizontalalignment = 'left',
             x=0.001,
             y=0.86,
             transform=fig.transFigure,
             fontsize=24,
             fontweight="bold",
             fontfamily="serif")

subtitle_t = 'Cantidad de créditos según su estado de pago (Al día / Atrasado) a Setiembre 2005'
plt.suptitle(subtitle_t,
            horizontalalignment = "left",
            x = 0.001,
            y = 0.84,
            transform = fig.transFigure,
            fontsize=16,
            fontweight="regular",
            fontfamily="serif")

#-------Etiquetas en Eje X y Y
label = "Estado del Préstamo a Set 2005"
ax.set_xlabel(label,
             ha="left",
             fontsize=10,
             fontweight="regular",
             fontfamily="sans")

ax.xaxis.set_label_coords(x=0,
                          y=-0.07,
                          transform=ax.transAxes)

ax.tick_params(axis='both',
               labelsize=12)

plt.subplots_adjust(top=0.70)

plt.show()

# %% [markdown]
# <h5 style="color:#0e535b; text-align: left">2.1.4 ¿Cuál es la relación entre el estado del crédito y la cantidad monetaria del crédito?</h5>
#
# <p style="text-align:justify">Con base en la información anterior al mes de setiembre de 2005, se establecerá la relación entre el estado del los créditos y su monto en Unidades Monetarias</p>

# %%
dfTemp = credit[["PAY_0","PAY_0(cat)","LIMIT_BAL"]]

# %%
fig,ax=plt.subplots(1,1,figsize=(15,6.9),dpi=100)

colors = np.random.rand(2396)
ax.scatter(dfTemp['PAY_0(cat)'],credit['LIMIT_BAL'],  c=colors, alpha=0.5)

#Formato del grafico
#-------Titulo y Subtitulo del grafico
title_t = "Gráfico 5: Créditos clasificados por estado del pago"
ax.set_title(title_t,
             horizontalalignment = 'left',
             x=0.001,
             y=0.86,
             transform=fig.transFigure,
             fontsize=24,
             fontweight="bold",
             fontfamily="serif")

subtitle_t = 'Relacion existente el estado del crédito y su valor en UM.'
plt.suptitle(subtitle_t,
            horizontalalignment = "left",
            x = 0.001,
            y = 0.84,
            transform = fig.transFigure,
            fontsize=16,
            fontweight="regular",
            fontfamily="serif")


plt.subplots_adjust(top=0.78)

plt.show()

# %% [markdown]
# <h4 style="color:#0e535b; text-align: left">2.2 Visualización de los Datos - Resultados </h4>
#
# <p style="text-align:justify">A continuación se procederá a remarcar los resultados obtenidos del análisis por medio de  visualización gráfica.</p>
#
# <ol>
#     <li>¿Cuál es el grupo etario que tiene mayor cantidad de créditos? R/ El grupo Adulto temprano tiene mas préstamos qie los otros dos grupos etarios juntos</li>
#     <li>¿Cuál es el grupo etario que ha tomado mayor cantidad de dinero prestado en Unidades Monetarias? R/ En Unidades Monetarias, el grupo adulto temprano sigue siendo el que tiene mayor representación, sin embargo la diferencia es ligeramente menor</li>
#     <li>¿Cuál es la cantidad de créditos que se encuentran atrasados? R/ La mayoría de los préstamos se encuentran al día y la tendencia parece indicar que las categorías que indican mayor atraso también tienen menos pagos atrasados. </li>
#     <li>¿Cuál es la relación entre el estado del préstamo y la cantidad del préstamo? R/ No se ve una relación directa.</li>
# </ol>

# %% [markdown]
# <h3 style="color:#0e535b; text-align: left">3. Correlación</h3>

# %%
corrMat = credit.corr()
print(corrMat)
# Out:
#                                         LIMIT_BAL  MARRIAGE       AGE  \
# LIMIT_BAL                                1.000000 -0.147788  0.154974
# MARRIAGE                                -0.147788  1.000000 -0.420270
# AGE                                      0.154974 -0.420270  1.000000
# PAY_0                                   -0.200540  0.025893 -0.017835
# PAY_2                                   -0.248233  0.037293 -0.029903
# PAY_3                                   -0.236194  0.038955 -0.037790
# PAY_4                                   -0.224340  0.046826 -0.024571
# PAY_5                                   -0.213442  0.044533 -0.012634
# PAY_6                                   -0.210881  0.041117 -0.009462
# BILL_AMT1                                0.361823 -0.040450  0.068263
# BILL_AMT2                                0.361342 -0.037658  0.061591
# BILL_AMT3                                0.365711 -0.047310  0.065932
# BILL_AMT4                                0.375659 -0.038152  0.058714
# BILL_AMT5                                0.365777 -0.038991  0.052104
# BILL_AMT6                                0.356559 -0.043290  0.064045
# PAY_AMT1                                 0.264026 -0.038972  0.035845
# PAY_AMT2                                 0.269277 -0.067744  0.071416
# PAY_AMT3                                 0.233681 -0.026502  0.040490
# PAY_AMT4                                 0.194202 -0.010184 -0.007273
# PAY_AMT5                                 0.222636 -0.036915  0.026600
# PAY_AMT6                                 0.208182 -0.018371  0.037726
# SEX_female                               0.013084 -0.028791 -0.117227
# SEX_male                                -0.013084  0.028791  0.117227
# EDUCATION_graduate school                0.228848  0.136935 -0.105091
# EDUCATION_high school                   -0.145685 -0.106092  0.252673
# EDUCATION_other                          0.004666  0.005129  0.008921
# EDUCATION_university                    -0.115704 -0.055570 -0.086934
# default payment next month_default      -0.084348 -0.025237  0.039677
# default payment next month_not default   0.084348  0.025237 -0.039677
#
#                                            PAY_0     PAY_2     PAY_3  \
# LIMIT_BAL                              -0.200540 -0.248233 -0.236194
# MARRIAGE                                0.025893  0.037293  0.038955
# AGE                                    -0.017835 -0.029903 -0.037790
# PAY_0                                   1.000000  0.637668  0.547805
# PAY_2                                   0.637668  1.000000  0.763806
# PAY_3                                   0.547805  0.763806  1.000000
# PAY_4                                   0.497509  0.667189  0.812452
# PAY_5                                   0.472577  0.639244  0.724154
# PAY_6                                   0.445626  0.606825  0.669614
# BILL_AMT1                               0.171638  0.225230  0.195056
# BILL_AMT2                               0.175226  0.229758  0.220140
# BILL_AMT3                               0.173459  0.232926  0.224046
# BILL_AMT4                               0.174051  0.229723  0.221919
# BILL_AMT5                               0.180882  0.233963  0.223246
# BILL_AMT6                               0.176785  0.223571  0.217238
# PAY_AMT1                               -0.104246 -0.067889 -0.003731
# PAY_AMT2                               -0.117068 -0.069403 -0.091800
# PAY_AMT3                               -0.031079 -0.016359 -0.018293
# PAY_AMT4                               -0.061638 -0.041619 -0.049315
# PAY_AMT5                               -0.042064 -0.036875 -0.032942
# PAY_AMT6                               -0.066021 -0.025573 -0.027555
# SEX_female                             -0.035623 -0.063752 -0.050640
# SEX_male                                0.035623  0.063752  0.050640
# EDUCATION_graduate school              -0.142563 -0.196535 -0.164077
# EDUCATION_high school                   0.055447  0.055588  0.064731
# EDUCATION_other                        -0.004659 -0.018184 -0.032034
# EDUCATION_university                    0.098640  0.153530  0.117473
# default payment next month_default      0.288299  0.202049  0.206223
# default payment next month_not default -0.288299 -0.202049 -0.206223
#
#                                            PAY_4     PAY_5     PAY_6  \
# LIMIT_BAL                              -0.224340 -0.213442 -0.210881
# MARRIAGE                                0.046826  0.044533  0.041117
# AGE                                    -0.024571 -0.012634 -0.009462
# PAY_0                                   0.497509  0.472577  0.445626
# PAY_2                                   0.667189  0.639244  0.606825
# PAY_3                                   0.812452  0.724154  0.669614
# PAY_4                                   1.000000  0.835864  0.742573
# PAY_5                                   0.835864  1.000000  0.815941
# PAY_6                                   0.742573  0.815941  1.000000
# BILL_AMT1                               0.200938  0.214870  0.212613
# BILL_AMT2                               0.221052  0.230721  0.229893
# BILL_AMT3                               0.253484  0.261140  0.252261
# BILL_AMT4                               0.249450  0.274443  0.258116
# BILL_AMT5                               0.254886  0.280365  0.284603
# BILL_AMT6                               0.244399  0.263086  0.273760
# PAY_AMT1                               -0.014056 -0.019604 -0.002178
# PAY_AMT2                                0.007803  0.016144 -0.015124
# PAY_AMT3                               -0.044739  0.013515  0.004286
# PAY_AMT4                               -0.026550 -0.056271  0.025300
# PAY_AMT5                               -0.022711 -0.038557 -0.044314
# PAY_AMT6                               -0.009108 -0.007577 -0.026467
# SEX_female                             -0.038189 -0.044360 -0.040419
# SEX_male                                0.038189  0.044360  0.040419
# EDUCATION_graduate school              -0.155414 -0.131661 -0.139426
# EDUCATION_high school                   0.052448  0.053426  0.054042
# EDUCATION_other                        -0.026775 -0.022265 -0.024223
# EDUCATION_university                    0.117245  0.092564  0.100021
# default payment next month_default      0.172565  0.187247  0.144420
# default payment next month_not default -0.172565 -0.187247 -0.144420
#
#                                         BILL_AMT1  ...  PAY_AMT5  PAY_AMT6  \
# LIMIT_BAL                                0.361823  ...  0.222636  0.208182
# MARRIAGE                                -0.040450  ... -0.036915 -0.018371
# AGE                                      0.068263  ...  0.026600  0.037726
# PAY_0                                    0.171638  ... -0.042064 -0.066021
# PAY_2                                    0.225230  ... -0.036875 -0.025573
# PAY_3                                    0.195056  ... -0.032942 -0.027555
# PAY_4                                    0.200938  ... -0.022711 -0.009108
# PAY_5                                    0.214870  ... -0.038557 -0.007577
# PAY_6                                    0.212613  ... -0.044314 -0.026467
# BILL_AMT1                                1.000000  ...  0.203028  0.113759
# BILL_AMT2                                0.953901  ...  0.188490  0.131757
# BILL_AMT3                                0.910261  ...  0.179528  0.173609
# BILL_AMT4                                0.879232  ...  0.157142  0.170907
# BILL_AMT5                                0.858022  ...  0.100021  0.159337
# BILL_AMT6                                0.842033  ...  0.287350  0.056766
# PAY_AMT1                                 0.193854  ...  0.097058  0.202027
# PAY_AMT2                                 0.175390  ...  0.164668  0.382537
# PAY_AMT3                                 0.305112  ...  0.122290  0.119466
# PAY_AMT4                                 0.157486  ...  0.093488  0.080065
# PAY_AMT5                                 0.203028  ...  1.000000  0.098268
# PAY_AMT6                                 0.113759  ...  0.098268  1.000000
# SEX_female                              -0.056271  ... -0.036136 -0.020722
# SEX_male                                 0.056271  ...  0.036136  0.020722
# EDUCATION_graduate school               -0.010959  ...  0.056079  0.031719
# EDUCATION_high school                   -0.014951  ... -0.044276 -0.044058
# EDUCATION_other                          0.018191  ... -0.000290  0.060369
# EDUCATION_university                     0.018650  ... -0.021727 -0.008657
# default payment next month_default       0.000581  ... -0.023946 -0.030268
# default payment next month_not default  -0.000581  ...  0.023946  0.030268
#
#                                         SEX_female  SEX_male  \
# LIMIT_BAL                                 0.013084 -0.013084
# MARRIAGE                                 -0.028791  0.028791
# AGE                                      -0.117227  0.117227
# PAY_0                                    -0.035623  0.035623
# PAY_2                                    -0.063752  0.063752
# PAY_3                                    -0.050640  0.050640
# PAY_4                                    -0.038189  0.038189
# PAY_5                                    -0.044360  0.044360
# PAY_6                                    -0.040419  0.040419
# BILL_AMT1                                -0.056271  0.056271
# BILL_AMT2                                -0.044604  0.044604
# BILL_AMT3                                -0.042932  0.042932
# BILL_AMT4                                -0.043453  0.043453
# BILL_AMT5                                -0.038864  0.038864
# BILL_AMT6                                -0.042528  0.042528
# PAY_AMT1                                  0.014640 -0.014640
# PAY_AMT2                                  0.001990 -0.001990
# PAY_AMT3                                  0.002756 -0.002756
# PAY_AMT4                                 -0.009158  0.009158
# PAY_AMT5                                 -0.036136  0.036136
# PAY_AMT6                                 -0.020722  0.020722
# SEX_female                                1.000000 -1.000000
# SEX_male                                 -1.000000  1.000000
# EDUCATION_graduate school                -0.054096  0.054096
# EDUCATION_high school                     0.019574 -0.019574
# EDUCATION_other                          -0.003888  0.003888
# EDUCATION_university                      0.038887 -0.038887
# default payment next month_default       -0.005722  0.005722
# default payment next month_not default    0.005722 -0.005722
#
#                                         EDUCATION_graduate school  \
# LIMIT_BAL                                                0.228848
# MARRIAGE                                                 0.136935
# AGE                                                     -0.105091
# PAY_0                                                   -0.142563
# PAY_2                                                   -0.196535
# PAY_3                                                   -0.164077
# PAY_4                                                   -0.155414
# PAY_5                                                   -0.131661
# PAY_6                                                   -0.139426
# BILL_AMT1                                               -0.010959
# BILL_AMT2                                               -0.004935
# BILL_AMT3                                               -0.006507
# BILL_AMT4                                                0.005471
# BILL_AMT5                                               -0.000098
# BILL_AMT6                                               -0.002568
# PAY_AMT1                                                 0.063353
# PAY_AMT2                                                 0.065485
# PAY_AMT3                                                 0.042466
# PAY_AMT4                                                 0.026074
# PAY_AMT5                                                 0.056079
# PAY_AMT6                                                 0.031719
# SEX_female                                              -0.054096
# SEX_male                                                 0.054096
# EDUCATION_graduate school                                1.000000
# EDUCATION_high school                                   -0.345797
# EDUCATION_other                                         -0.068023
# EDUCATION_university                                    -0.706500
# default payment next month_default                      -0.043638
# default payment next month_not default                   0.043638
#
#                                         EDUCATION_high school  \
# LIMIT_BAL                                           -0.145685
# MARRIAGE                                            -0.106092
# AGE                                                  0.252673
# PAY_0                                                0.055447
# PAY_2                                                0.055588
# PAY_3                                                0.064731
# PAY_4                                                0.052448
# PAY_5                                                0.053426
# PAY_6                                                0.054042
# BILL_AMT1                                           -0.014951
# BILL_AMT2                                           -0.019785
# BILL_AMT3                                           -0.013288
# BILL_AMT4                                           -0.020721
# BILL_AMT5                                           -0.017064
# BILL_AMT6                                           -0.010815
# PAY_AMT1                                            -0.054214
# PAY_AMT2                                            -0.030528
# PAY_AMT3                                            -0.025020
# PAY_AMT4                                            -0.058686
# PAY_AMT5                                            -0.044276
# PAY_AMT6                                            -0.044058
# SEX_female                                           0.019574
# SEX_male                                            -0.019574
# EDUCATION_graduate school                           -0.345797
# EDUCATION_high school                                1.000000
# EDUCATION_other                                     -0.038479
# EDUCATION_university                                -0.399650
# default payment next month_default                   0.044065
# default payment next month_not default              -0.044065
#
#                                         EDUCATION_other  EDUCATION_university  \
# LIMIT_BAL                                      0.004666             -0.115704
# MARRIAGE                                       0.005129             -0.055570
# AGE                                            0.008921             -0.086934
# PAY_0                                         -0.004659              0.098640
# PAY_2                                         -0.018184              0.153530
# PAY_3                                         -0.032034              0.117473
# PAY_4                                         -0.026775              0.117245
# PAY_5                                         -0.022265              0.092564
# PAY_6                                         -0.024223              0.100021
# BILL_AMT1                                      0.018191              0.018650
# BILL_AMT2                                      0.023348              0.015474
# BILL_AMT3                                      0.023222              0.012198
# BILL_AMT4                                      0.016818              0.007153
# BILL_AMT5                                      0.015527              0.010090
# BILL_AMT6                                      0.009893              0.008831
# PAY_AMT1                                       0.033105             -0.027229
# PAY_AMT2                                      -0.003326             -0.040598
# PAY_AMT3                                       0.033596             -0.028650
# PAY_AMT4                                       0.049482              0.009618
# PAY_AMT5                                      -0.000290             -0.021727
# PAY_AMT6                                       0.060369             -0.008657
# SEX_female                                    -0.003888              0.038887
# SEX_male                                       0.003888             -0.038887
# EDUCATION_graduate school                     -0.068023             -0.706500
# EDUCATION_high school                         -0.038479             -0.399650
# EDUCATION_other                                1.000000             -0.078617
# EDUCATION_university                          -0.078617              1.000000
# default payment next month_default            -0.034015              0.015703
# default payment next month_not default         0.034015             -0.015703
#
#                                         default payment next month_default  \
# LIMIT_BAL                                                        -0.084348
# MARRIAGE                                                         -0.025237
# AGE                                                               0.039677
# PAY_0                                                             0.288299
# PAY_2                                                             0.202049
# PAY_3                                                             0.206223
# PAY_4                                                             0.172565
# PAY_5                                                             0.187247
# PAY_6                                                             0.144420
# BILL_AMT1                                                         0.000581
# BILL_AMT2                                                         0.004263
# BILL_AMT3                                                         0.010062
# BILL_AMT4                                                         0.008793
# BILL_AMT5                                                         0.002888
# BILL_AMT6                                                         0.005231
# PAY_AMT1                                                         -0.082471
# PAY_AMT2                                                         -0.066537
# PAY_AMT3                                                         -0.034310
# PAY_AMT4                                                         -0.057266
# PAY_AMT5                                                         -0.023946
# PAY_AMT6                                                         -0.030268
# SEX_female                                                       -0.005722
# SEX_male                                                          0.005722
# EDUCATION_graduate school                                        -0.043638
# EDUCATION_high school                                             0.044065
# EDUCATION_other                                                  -0.034015
# EDUCATION_university                                              0.015703
# default payment next month_default                                1.000000
# default payment next month_not default                           -1.000000
#
#                                         default payment next month_not default
# LIMIT_BAL                                                             0.084348
# MARRIAGE                                                              0.025237
# AGE                                                                  -0.039677
# PAY_0                                                                -0.288299
# PAY_2                                                                -0.202049
# PAY_3                                                                -0.206223
# PAY_4                                                                -0.172565
# PAY_5                                                                -0.187247
# PAY_6                                                                -0.144420
# BILL_AMT1                                                            -0.000581
# BILL_AMT2                                                            -0.004263
# BILL_AMT3                                                            -0.010062
# BILL_AMT4                                                            -0.008793
# BILL_AMT5                                                            -0.002888
# BILL_AMT6                                                            -0.005231
# PAY_AMT1                                                              0.082471
# PAY_AMT2                                                              0.066537
# PAY_AMT3                                                              0.034310
# PAY_AMT4                                                              0.057266
# PAY_AMT5                                                              0.023946
# PAY_AMT6                                                              0.030268
# SEX_female                                                            0.005722
# SEX_male                                                             -0.005722
# EDUCATION_graduate school                                             0.043638
# EDUCATION_high school                                                -0.044065
# EDUCATION_other                                                       0.034015
# EDUCATION_university                                                 -0.015703
# default payment next month_default                                   -1.000000
# default payment next month_not default                                1.000000
#
# [29 rows x 29 columns]
# C:\Users\sergi\AppData\Local\Temp\ipykernel_14536\4264262329.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corrMat = credit.corr()

# %% [markdown]
# <h3 style="color:#0e535b; text-align: left">4. Covarianza</h3>

# %%
covMat = credit.cov()
print(covMat)
# Out:
#                                            LIMIT_BAL      MARRIAGE  \
# LIMIT_BAL                               1.676861e+10 -10058.566644
# MARRIAGE                               -1.005857e+04      0.276248
# AGE                                     1.896911e+05     -2.087939
# PAY_0                                  -2.917502e+04      0.015290
# PAY_2                                  -3.882758e+04      0.023676
# PAY_3                                  -3.815289e+04      0.025540
# PAY_4                                  -3.417397e+04      0.028952
# PAY_5                                  -3.197111e+04      0.027074
# PAY_6                                  -3.227379e+04      0.025541
# BILL_AMT1                               3.648630e+09  -1655.601465
# BILL_AMT2                               3.532902e+09  -1494.415030
# BILL_AMT3                               3.297613e+09  -1731.488883
# BILL_AMT4                               3.313588e+09  -1365.926518
# BILL_AMT5                               3.046906e+09  -1318.268027
# BILL_AMT6                               3.022809e+09  -1489.604090
# PAY_AMT1                                4.684651e+08   -280.664936
# PAY_AMT2                                5.096867e+08   -520.449351
# PAY_AMT3                                6.704545e+08   -308.626590
# PAY_AMT4                                3.584094e+08    -76.286655
# PAY_AMT5                                4.871168e+08   -327.827663
# PAY_AMT6                                5.412305e+08   -193.856700
# SEX_female                              8.370527e+02     -0.007476
# SEX_male                               -8.370527e+02      0.007476
# EDUCATION_graduate school               1.438256e+04      0.034931
# EDUCATION_high school                  -6.980047e+03     -0.020631
# EDUCATION_other                         5.218161e+01      0.000233
# EDUCATION_university                   -7.454697e+03     -0.014532
# default payment next month_default     -4.500301e+03     -0.005465
# default payment next month_not default  4.500301e+03      0.005465
#
#                                                   AGE         PAY_0  \
# LIMIT_BAL                               189691.134493 -29175.023787
# MARRIAGE                                    -2.087939      0.015290
# AGE                                         89.346812     -0.189402
# PAY_0                                       -0.189402      1.262192
# PAY_2                                       -0.341421      0.865345
# PAY_3                                       -0.445582      0.767712
# PAY_4                                       -0.273211      0.657512
# PAY_5                                       -0.138139      0.614136
# PAY_6                                       -0.105708      0.591692
# BILL_AMT1                                50246.908772  15016.264546
# BILL_AMT2                                43956.155322  14863.644606
# BILL_AMT3                                43395.642119  13569.784507
# BILL_AMT4                                37803.951152  13319.744428
# BILL_AMT5                                31681.465104  13072.301012
# BILL_AMT6                                39632.598662  13002.822429
# PAY_AMT1                                  4642.480802  -1604.735437
# PAY_AMT2                                  9867.140374  -1922.451171
# PAY_AMT3                                  8479.786089   -773.618322
# PAY_AMT4                                  -979.759275   -986.931828
# PAY_AMT5                                  4248.225575   -798.476308
# PAY_AMT6                                  7159.267139  -1489.141217
# SEX_female                                  -0.547430     -0.019772
# SEX_male                                     0.547430      0.019772
# EDUCATION_graduate school                   -0.482112     -0.077734
# EDUCATION_high school                        0.883679      0.023048
# EDUCATION_other                              0.007283     -0.000452
# EDUCATION_university                        -0.408850      0.055138
# default payment next month_default           0.154526      0.133452
# default payment next month_not default      -0.154526     -0.133452
#
#                                                PAY_2         PAY_3  \
# LIMIT_BAL                              -38827.576232 -38152.885289
# MARRIAGE                                    0.023676      0.025540
# AGE                                        -0.341421     -0.445582
# PAY_0                                       0.865345      0.767712
# PAY_2                                       1.459028      1.150865
# PAY_3                                       1.150865      1.556034
# PAY_4                                       0.948026      1.192194
# PAY_5                                       0.893157      1.044888
# PAY_6                                       0.866280      0.987183
# BILL_AMT1                               21185.747455  18947.564090
# BILL_AMT2                               20953.985093  20733.484552
# BILL_AMT3                               19591.343794  19460.770094
# BILL_AMT4                               18901.320245  18856.502878
# BILL_AMT5                               18179.140215  17913.809748
# BILL_AMT6                               17679.788134  17740.938882
# PAY_AMT1                                -1123.599456    -63.777375
# PAY_AMT2                                -1225.365547  -1673.813619
# PAY_AMT3                                 -437.819175   -505.586016
# PAY_AMT4                                 -716.482016   -876.738005
# PAY_AMT5                                 -752.573375   -694.302736
# PAY_AMT6                                 -620.155882   -690.082246
# SEX_female                                 -0.038044     -0.031208
# SEX_male                                    0.038044      0.031208
# EDUCATION_graduate school                  -0.115216     -0.099334
# EDUCATION_high school                       0.024843      0.029876
# EDUCATION_other                            -0.001897     -0.003451
# EDUCATION_university                        0.092270      0.072909
# default payment next month_default          0.100556      0.105990
# default payment next month_not default     -0.100556     -0.105990
#
#                                                PAY_4         PAY_5  \
# LIMIT_BAL                              -34173.974718 -31971.107029
# MARRIAGE                                    0.028952      0.027074
# AGE                                        -0.273211     -0.138139
# PAY_0                                       0.657512      0.614136
# PAY_2                                       0.948026      0.893157
# PAY_3                                       1.192194      1.044888
# PAY_4                                       1.383820      1.137378
# PAY_5                                       1.137378      1.338008
# PAY_6                                       1.032386      1.115453
# BILL_AMT1                               18407.182233  19354.817317
# BILL_AMT2                               19633.585762  20150.291028
# BILL_AMT3                               20763.667396  21033.736692
# BILL_AMT4                               19988.446738  21624.062200
# BILL_AMT5                               19287.669561  20861.557506
# BILL_AMT6                               18822.200899  19923.149734
# PAY_AMT1                                 -226.567489   -310.713388
# PAY_AMT2                                  134.163737    272.952573
# PAY_AMT3                                -1166.056842    346.371171
# PAY_AMT4                                 -445.118731   -927.660381
# PAY_AMT5                                 -451.406766   -753.560233
# PAY_AMT6                                 -215.097122   -175.970936
# SEX_female                                 -0.022194     -0.025351
# SEX_male                                    0.022194      0.025351
# EDUCATION_graduate school                  -0.088730     -0.073914
# EDUCATION_high school                       0.022828      0.022866
# EDUCATION_other                            -0.002720     -0.002224
# EDUCATION_university                        0.068623      0.053273
# default payment next month_default          0.083640      0.089241
# default payment next month_not default     -0.083640     -0.089241
#
#                                                PAY_6     BILL_AMT1  ...  \
# LIMIT_BAL                              -32273.789649  3.648630e+09  ...
# MARRIAGE                                    0.025541 -1.655601e+03  ...
# AGE                                        -0.105708  5.024691e+04  ...
# PAY_0                                       0.591692  1.501626e+04  ...
# PAY_2                                       0.866280  2.118575e+04  ...
# PAY_3                                       0.987183  1.894756e+04  ...
# PAY_4                                       1.032386  1.840718e+04  ...
# PAY_5                                       1.115453  1.935482e+04  ...
# PAY_6                                       1.396775  1.956765e+04  ...
# BILL_AMT1                               19567.654336  6.064145e+09  ...
# BILL_AMT2                               20514.188281  5.608573e+09  ...
# BILL_AMT3                               20759.956152  4.935875e+09  ...
# BILL_AMT4                               20779.500693  4.663853e+09  ...
# BILL_AMT5                               21636.982374  4.298111e+09  ...
# BILL_AMT6                               21181.806567  4.292837e+09  ...
# PAY_AMT1                                  -35.273759  2.068437e+08  ...
# PAY_AMT2                                 -261.275934  1.996389e+08  ...
# PAY_AMT3                                  112.218752  5.264310e+08  ...
# PAY_AMT4                                  426.148894  1.747854e+08  ...
# PAY_AMT5                                 -884.902694  2.671349e+08  ...
# PAY_AMT6                                 -628.010958  1.778536e+08  ...
# SEX_female                                 -0.023600 -2.164855e+03  ...
# SEX_male                                    0.023600  2.164855e+03  ...
# EDUCATION_graduate school                  -0.079974 -4.141873e+02  ...
# EDUCATION_high school                       0.023632 -4.307675e+02  ...
# EDUCATION_other                            -0.002472  1.223444e+02  ...
# EDUCATION_university                        0.058815  7.226105e+02  ...
# default payment next month_default          0.070325  1.864294e+01  ...
# default payment next month_not default     -0.070325 -1.864294e+01  ...
#
#                                             PAY_AMT5      PAY_AMT6  \
# LIMIT_BAL                               4.871168e+08  5.412305e+08
# MARRIAGE                               -3.278277e+02 -1.938567e+02
# AGE                                     4.248226e+03  7.159267e+03
# PAY_0                                  -7.984763e+02 -1.489141e+03
# PAY_2                                  -7.525734e+02 -6.201559e+02
# PAY_3                                  -6.943027e+02 -6.900822e+02
# PAY_4                                  -4.514068e+02 -2.150971e+02
# PAY_5                                  -7.535602e+02 -1.759709e+02
# PAY_6                                  -8.849027e+02 -6.280110e+02
# BILL_AMT1                               2.671349e+08  1.778536e+08
# BILL_AMT2                               2.404592e+08  1.997233e+08
# BILL_AMT3                               2.112206e+08  2.427047e+08
# BILL_AMT4                               1.808583e+08  2.337268e+08
# BILL_AMT5                               1.087117e+08  2.057792e+08
# BILL_AMT6                               3.178565e+08  7.461220e+07
# PAY_AMT1                                2.246990e+07  5.557542e+07
# PAY_AMT2                                4.066811e+07  1.122590e+08
# PAY_AMT3                                4.578026e+07  5.314137e+07
# PAY_AMT4                                2.251237e+07  2.290929e+07
# PAY_AMT5                                2.854824e+08  3.333430e+07
# PAY_AMT6                                3.333430e+07  4.030723e+08
# SEX_female                             -3.016448e+02 -2.055320e+02
# SEX_male                                3.016448e+02  2.055320e+02
# EDUCATION_graduate school               4.598656e+02  3.090709e+02
# EDUCATION_high school                  -2.767914e+02 -3.272768e+02
# EDUCATION_other                        -4.236333e-01  1.046778e+02
# EDUCATION_university                   -1.826506e+02 -8.647187e+01
# default payment next month_default     -1.667000e+02 -2.503787e+02
# default payment next month_not default  1.667000e+02  2.503787e+02
#
#                                          SEX_female     SEX_male  \
# LIMIT_BAL                                837.052708  -837.052708
# MARRIAGE                                  -0.007476     0.007476
# AGE                                       -0.547430     0.547430
# PAY_0                                     -0.019772     0.019772
# PAY_2                                     -0.038044     0.038044
# PAY_3                                     -0.031208     0.031208
# PAY_4                                     -0.022194     0.022194
# PAY_5                                     -0.025351     0.025351
# PAY_6                                     -0.023600     0.023600
# BILL_AMT1                              -2164.854740  2164.854740
# BILL_AMT2                              -1663.790584  1663.790584
# BILL_AMT3                              -1476.905788  1476.905788
# BILL_AMT4                              -1462.298256  1462.298256
# BILL_AMT5                              -1235.106043  1235.106043
# BILL_AMT6                              -1375.511484  1375.511484
# PAY_AMT1                                  99.100683   -99.100683
# PAY_AMT2                                  14.368729   -14.368729
# PAY_AMT3                                  30.170764   -30.170764
# PAY_AMT4                                 -64.481402    64.481402
# PAY_AMT5                                -301.644837   301.644837
# PAY_AMT6                                -205.532036   205.532036
# SEX_female                                 0.244076    -0.244076
# SEX_male                                  -0.244076     0.244076
# EDUCATION_graduate school                 -0.012971     0.012971
# EDUCATION_high school                      0.003578    -0.003578
# EDUCATION_other                           -0.000166     0.000166
# EDUCATION_university                       0.009559    -0.009559
# default payment next month_default        -0.001165     0.001165
# default payment next month_not default     0.001165    -0.001165
#
#                                         EDUCATION_graduate school  \
# LIMIT_BAL                                            14382.561750
# MARRIAGE                                                 0.034931
# AGE                                                     -0.482112
# PAY_0                                                   -0.077734
# PAY_2                                                   -0.115216
# PAY_3                                                   -0.099334
# PAY_4                                                   -0.088730
# PAY_5                                                   -0.073914
# PAY_6                                                   -0.079974
# BILL_AMT1                                             -414.187301
# BILL_AMT2                                             -180.838134
# BILL_AMT3                                             -219.921094
# BILL_AMT4                                              180.874028
# BILL_AMT5                                               -3.066822
# BILL_AMT6                                              -81.608876
# PAY_AMT1                                               421.299781
# PAY_AMT2                                               464.556616
# PAY_AMT3                                               456.649569
# PAY_AMT4                                               180.353335
# PAY_AMT5                                               459.865598
# PAY_AMT6                                               309.070929
# SEX_female                                              -0.012971
# SEX_male                                                 0.012971
# EDUCATION_graduate school                                0.235550
# EDUCATION_high school                                   -0.062095
# EDUCATION_other                                         -0.002851
# EDUCATION_university                                    -0.170603
# default payment next month_default                      -0.008726
# default payment next month_not default                   0.008726
#
#                                         EDUCATION_high school  \
# LIMIT_BAL                                        -6980.046772
# MARRIAGE                                            -0.020631
# AGE                                                  0.883679
# PAY_0                                                0.023048
# PAY_2                                                0.024843
# PAY_3                                                0.029876
# PAY_4                                                0.022828
# PAY_5                                                0.022866
# PAY_6                                                0.023632
# BILL_AMT1                                         -430.767526
# BILL_AMT2                                         -552.702876
# BILL_AMT3                                         -342.354529
# BILL_AMT4                                         -522.229340
# BILL_AMT5                                         -406.127536
# BILL_AMT6                                         -261.977026
# PAY_AMT1                                          -274.845339
# PAY_AMT2                                          -165.101794
# PAY_AMT3                                          -205.108106
# PAY_AMT4                                          -309.462428
# PAY_AMT5                                          -276.791369
# PAY_AMT6                                          -327.276836
# SEX_female                                           0.003578
# SEX_male                                            -0.003578
# EDUCATION_graduate school                           -0.062095
# EDUCATION_high school                                0.136896
# EDUCATION_other                                     -0.001230
# EDUCATION_university                                -0.073571
# default payment next month_default                   0.006718
# default payment next month_not default              -0.006718
#
#                                         EDUCATION_other  EDUCATION_university  \
# LIMIT_BAL                                     52.181611          -7454.696589
# MARRIAGE                                       0.000233             -0.014532
# AGE                                            0.007283             -0.408850
# PAY_0                                         -0.000452              0.055138
# PAY_2                                         -0.001897              0.092270
# PAY_3                                         -0.003451              0.072909
# PAY_4                                         -0.002720              0.068623
# PAY_5                                         -0.002224              0.053273
# PAY_6                                         -0.002472              0.058815
# BILL_AMT1                                    122.344376            722.610451
# BILL_AMT2                                    152.254012            581.286998
# BILL_AMT3                                    139.656979            422.618644
# BILL_AMT4                                     98.941101            242.414212
# BILL_AMT5                                     86.264362            322.929996
# BILL_AMT6                                     55.940137            287.645765
# PAY_AMT1                                      39.175795           -185.630237
# PAY_AMT2                                      -4.199127           -295.255695
# PAY_AMT3                                      64.288524           -315.829986
# PAY_AMT4                                      60.906999             68.202094
# PAY_AMT5                                      -0.423633           -182.650596
# PAY_AMT6                                     104.677781            -86.471873
# SEX_female                                    -0.000166              0.009559
# SEX_male                                       0.000166             -0.009559
# EDUCATION_graduate school                     -0.002851             -0.170603
# EDUCATION_high school                         -0.001230             -0.073571
# EDUCATION_other                                0.007459             -0.003378
# EDUCATION_university                          -0.003378              0.247553
# default payment next month_default            -0.001210              0.003219
# default payment next month_not default         0.001210             -0.003219
#
#                                         default payment next month_default  \
# LIMIT_BAL                                                     -4500.301477
# MARRIAGE                                                         -0.005465
# AGE                                                               0.154526
# PAY_0                                                             0.133452
# PAY_2                                                             0.100556
# PAY_3                                                             0.105990
# PAY_4                                                             0.083640
# PAY_5                                                             0.089241
# PAY_6                                                             0.070325
# BILL_AMT1                                                        18.642938
# BILL_AMT2                                                       132.609272
# BILL_AMT3                                                       288.668158
# BILL_AMT4                                                       246.781213
# BILL_AMT5                                                        76.541027
# BILL_AMT6                                                       141.095667
# PAY_AMT1                                                       -465.587609
# PAY_AMT2                                                       -400.720338
# PAY_AMT3                                                       -313.213469
# PAY_AMT4                                                       -336.274367
# PAY_AMT5                                                       -166.700008
# PAY_AMT6                                                       -250.378689
# SEX_female                                                       -0.001165
# SEX_male                                                          0.001165
# EDUCATION_graduate school                                        -0.008726
# EDUCATION_high school                                             0.006718
# EDUCATION_other                                                  -0.001210
# EDUCATION_university                                              0.003219
# default payment next month_default                                0.169762
# default payment next month_not default                           -0.169762
#
#                                         default payment next month_not default
# LIMIT_BAL                                                          4500.301477
# MARRIAGE                                                              0.005465
# AGE                                                                  -0.154526
# PAY_0                                                                -0.133452
# PAY_2                                                                -0.100556
# PAY_3                                                                -0.105990
# PAY_4                                                                -0.083640
# PAY_5                                                                -0.089241
# PAY_6                                                                -0.070325
# BILL_AMT1                                                           -18.642938
# BILL_AMT2                                                          -132.609272
# BILL_AMT3                                                          -288.668158
# BILL_AMT4                                                          -246.781213
# BILL_AMT5                                                           -76.541027
# BILL_AMT6                                                          -141.095667
# PAY_AMT1                                                            465.587609
# PAY_AMT2                                                            400.720338
# PAY_AMT3                                                            313.213469
# PAY_AMT4                                                            336.274367
# PAY_AMT5                                                            166.700008
# PAY_AMT6                                                            250.378689
# SEX_female                                                            0.001165
# SEX_male                                                             -0.001165
# EDUCATION_graduate school                                             0.008726
# EDUCATION_high school                                                -0.006718
# EDUCATION_other                                                       0.001210
# EDUCATION_university                                                 -0.003219
# default payment next month_default                                   -0.169762
# default payment next month_not default                                0.169762
#
# [29 rows x 29 columns]
# C:\Users\sergi\AppData\Local\Temp\ipykernel_14536\3199804705.py:1: FutureWarning: The default value of numeric_only in DataFrame.cov is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   covMat = credit.cov()
